# %%
import pandas as pd
import matplotlib.pyplot as plt
#matplotlib is library pyplot is one of the packages/folders
import sklearn

# %%
data = pd.read_csv('LIBOR_GOFO_GLR.CSV')

# %%
data.head()
# Out:
#          Date  GOFO_1M  GOFO_2M  GOFO_3M  GOFO_6M  GOFO_12M  LIBOR_1M  \
# 0  2012-12-31  0.29400    0.324  0.34800  0.41800   0.46600    0.2087
# 1  2012-12-28  0.28400    0.320  0.34600  0.42400   0.47400    0.2097
# 2  2012-12-27  0.30600    0.332  0.35800  0.42800   0.47400    0.2117
# 3  2012-12-24  0.32200    0.346  0.37800  0.43600   0.48400    0.2097
# 4  2012-12-21  0.32333    0.360  0.38833  0.44667   0.48167    0.2097
#
#    LIBOR_2M  LIBOR_3M  LIBOR_6M  LIBOR_12M   GLR_1M  GLR_2M   GLR_3M   GLR_6M  \
# 0    0.2535     0.306   0.50825     0.8435 -0.08530 -0.0705 -0.04200  0.09025
# 1    0.2535     0.308   0.50825     0.8435 -0.07430 -0.0665 -0.03800  0.08425
# 2    0.2550     0.311   0.51025     0.8435 -0.09430 -0.0770 -0.04700  0.08225
# 3    0.2540     0.310   0.51025     0.8430 -0.11230 -0.0920 -0.06800  0.07425
# 4    0.2540     0.310   0.51025     0.8430 -0.11363 -0.1060 -0.07833  0.06358
#
#    GLR_12M
# 0  0.37750
# 1  0.36950
# 2  0.36950
# 3  0.35900
# 4  0.36133

# %%
data.set_index("Date", inplace=True)

# %%
data.head()
# Out:
#             GOFO_1M  GOFO_2M  GOFO_3M  GOFO_6M  GOFO_12M  LIBOR_1M  LIBOR_2M  \
# Date
# 2012-12-31  0.29400    0.324  0.34800  0.41800   0.46600    0.2087    0.2535
# 2012-12-28  0.28400    0.320  0.34600  0.42400   0.47400    0.2097    0.2535
# 2012-12-27  0.30600    0.332  0.35800  0.42800   0.47400    0.2117    0.2550
# 2012-12-24  0.32200    0.346  0.37800  0.43600   0.48400    0.2097    0.2540
# 2012-12-21  0.32333    0.360  0.38833  0.44667   0.48167    0.2097    0.2540
#
#             LIBOR_3M  LIBOR_6M  LIBOR_12M   GLR_1M  GLR_2M   GLR_3M   GLR_6M  \
# Date
# 2012-12-31     0.306   0.50825     0.8435 -0.08530 -0.0705 -0.04200  0.09025
# 2012-12-28     0.308   0.50825     0.8435 -0.07430 -0.0665 -0.03800  0.08425
# 2012-12-27     0.311   0.51025     0.8435 -0.09430 -0.0770 -0.04700  0.08225
# 2012-12-24     0.310   0.51025     0.8430 -0.11230 -0.0920 -0.06800  0.07425
# 2012-12-21     0.310   0.51025     0.8430 -0.11363 -0.1060 -0.07833  0.06358
#
#             GLR_12M
# ...

# %%
data.plot()

# %%
data['GLR_1M'].plot()
